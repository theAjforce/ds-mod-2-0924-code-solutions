# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_json('Beauty.json',lines=True)

# %%
# Out:
#       overall  verified   reviewTime      reviewerID        asin  \
# 0           5      True   09 1, 2016  A3CIUOJXQ5VDQ2  B0000530HU
# 1           5      True  11 14, 2013  A3H7T87S984REU  B0000530HU
# 2           1      True  08 18, 2013  A3J034YH7UG4KT  B0000530HU
# 3           5     False   05 3, 2011  A2UEO5XR3598GI  B0000530HU
# 4           5      True   05 6, 2011  A3SFRT223XXWF7  B00006L9LC
# ...       ...       ...          ...             ...         ...
# 5264        5      True  08 23, 2018   AUX122XW8ONG6  B01DLR9IDI
# 5265        5      True  08 23, 2018   AUX122XW8ONG6  B01DLR9IDI
# 5266        5      True  08 23, 2018   AUX122XW8ONG6  B01DLR9IDI
# 5267        5      True  08 23, 2018   AUX122XW8ONG6  B01DLR9IDI
# 5268        5      True  08 23, 2018   AUX122XW8ONG6  B01DLR9IDI
#
#                                                   style     reviewerName  \
# 0     {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...         Shelly F
# 1     {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...     houserules18
# 2     {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...             Adam
# 3     {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...           Rich K
# 4                             {'Size:': ' 200ml/6.7oz'}  C. C. Christian
# ...                                                 ...              ...
# 5264                     {'Design:': ' ETA-C6B5F7C374'}   Amzon Customer
# 5265                     {'Design:': ' ETA-7117EE3788'}   Amzon Customer
# 5266                     {'Design:': ' ETA-BF66BD2F87'}   Amzon Customer
# 5267                     {'Design:': ' ETA-03868FCB34'}   Amzon Customer
# 5268                     {'Design:': ' ETA-C4893097E9'}   Amzon Customer
#
#                                              reviewText  \
# 0                      As advertised. Reasonably priced
# 1     Like the oder and the feel when I put it on my...
# 2     I bought this to smell nice after I shave.  Wh...
# 3     HEY!! I am an Aqua Velva Man and absolutely lo...
# 4     If you ever want to feel pampered by a shampoo...
# ...                                                 ...
# 5264  I have genetic undereye darkness. Ive accepted...
# 5265                    I absolutely love this eye gel.
# 5266  The eye gel is easy to apply and I use it morn...
# 5267                     Ok this eye gel is good stuff.
# 5268  This is the first eye gel/cream that actually ...
#
#                                                 summary  unixReviewTime  vote  \
# 0                                            Five Stars      1472710720  None
# 1                                     Good for the face      1384468143  None
# 2                                          Smells awful      1376831082  None
# 3     Truth is There IS Nothing Like an AQUA VELVA MAN.      1304424552    25
# 4                                       Bvlgari Shampoo      1304690578     3
# ...                                                 ...             ...   ...
# 5264                                    Pretty Sweet!!!      1535043957     2
# 5265                                      As advertised      1535025109  None
# 5266                                I'm very happy with      1535067647  None
# 5267                                   Does it's thing!      1535028621  None
# 5268                                              Happy      1535048160  None
#
#      image                date
# 0     None 2016-09-01 06:18:40
# 1     None 2013-11-14 22:29:03
# 2     None 2013-08-18 13:04:42
# 3     None 2011-05-03 12:09:12
# 4     None 2011-05-06 14:02:58
# ...    ...                 ...
# 5264  None 2018-08-23 17:05:57
# 5265  None 2018-08-23 11:51:49
# 5266  None 2018-08-23 23:40:47
# 5267  None 2018-08-23 12:50:21
# 5268  None 2018-08-23 18:16:00
#
# [5269 rows x 13 columns]

# %%
overall_groups = df.groupby('asin').agg({'overall':[np.size,np.sum,np.mean]})
# Out:
# /var/folders/b2/02ycqbbj4nq9mtszv2phxc780000gn/T/ipykernel_6288/1199095337.py:1: FutureWarning: The provided callable <function sum at 0x110b258a0> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   overall_groups = df.groupby('asin').agg({'overall':[np.size,np.sum,np.mean]})
# /var/folders/b2/02ycqbbj4nq9mtszv2phxc780000gn/T/ipykernel_6288/1199095337.py:1: FutureWarning: The provided callable <function mean at 0x110b26ca0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   overall_groups = df.groupby('asin').agg({'overall':[np.size,np.sum,np.mean]})

# %%
popular_products = overall_groups.sort_values(('overall','sum'),ascending=False)

# %%
df
# Out:
#       overall  verified   reviewTime      reviewerID        asin  \
# 0           5      True   09 1, 2016  A3CIUOJXQ5VDQ2  B0000530HU
# 1           5      True  11 14, 2013  A3H7T87S984REU  B0000530HU
# 2           1      True  08 18, 2013  A3J034YH7UG4KT  B0000530HU
# 3           5     False   05 3, 2011  A2UEO5XR3598GI  B0000530HU
# 4           5      True   05 6, 2011  A3SFRT223XXWF7  B00006L9LC
# ...       ...       ...          ...             ...         ...
# 5264        5      True  08 23, 2018   AUX122XW8ONG6  B01DLR9IDI
# 5265        5      True  08 23, 2018   AUX122XW8ONG6  B01DLR9IDI
# 5266        5      True  08 23, 2018   AUX122XW8ONG6  B01DLR9IDI
# 5267        5      True  08 23, 2018   AUX122XW8ONG6  B01DLR9IDI
# 5268        5      True  08 23, 2018   AUX122XW8ONG6  B01DLR9IDI
#
#                                                   style     reviewerName  \
# 0     {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...         Shelly F
# 1     {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...     houserules18
# 2     {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...             Adam
# 3     {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...           Rich K
# 4                             {'Size:': ' 200ml/6.7oz'}  C. C. Christian
# ...                                                 ...              ...
# 5264                     {'Design:': ' ETA-C6B5F7C374'}   Amzon Customer
# 5265                     {'Design:': ' ETA-7117EE3788'}   Amzon Customer
# 5266                     {'Design:': ' ETA-BF66BD2F87'}   Amzon Customer
# 5267                     {'Design:': ' ETA-03868FCB34'}   Amzon Customer
# 5268                     {'Design:': ' ETA-C4893097E9'}   Amzon Customer
#
#                                              reviewText  \
# 0                      As advertised. Reasonably priced
# 1     Like the oder and the feel when I put it on my...
# 2     I bought this to smell nice after I shave.  Wh...
# 3     HEY!! I am an Aqua Velva Man and absolutely lo...
# 4     If you ever want to feel pampered by a shampoo...
# ...                                                 ...
# 5264  I have genetic undereye darkness. Ive accepted...
# 5265                    I absolutely love this eye gel.
# 5266  The eye gel is easy to apply and I use it morn...
# 5267                     Ok this eye gel is good stuff.
# 5268  This is the first eye gel/cream that actually ...
#
#                                                 summary  unixReviewTime  vote  \
# 0                                            Five Stars      1472710720  None
# 1                                     Good for the face      1384468143  None
# 2                                          Smells awful      1376831082  None
# 3     Truth is There IS Nothing Like an AQUA VELVA MAN.      1304424552    25
# 4                                       Bvlgari Shampoo      1304690578     3
# ...                                                 ...             ...   ...
# 5264                                    Pretty Sweet!!!      1535043957     2
# 5265                                      As advertised      1535025109  None
# 5266                                I'm very happy with      1535067647  None
# 5267                                   Does it's thing!      1535028621  None
# 5268                                              Happy      1535048160  None
#
#      image                date   next_item
# 0     None 2016-09-01 06:18:40  B000FTYALG
# 1     None 2013-11-14 22:29:03  B000FTYALG
# 2     None 2013-08-18 13:04:42  B000FTYALG
# 3     None 2011-05-03 12:09:12  B000FTYALG
# 4     None 2011-05-06 14:02:58  B0012Y0ZG2
# ...    ...                 ...         ...
# 5264  None 2018-08-23 17:05:57  B01DLR9IDI
# 5265  None 2018-08-23 11:51:49  B01DLR9IDI
# 5266  None 2018-08-23 23:40:47  B01DLR9IDI
# 5267  None 2018-08-23 12:50:21  B01DLR9IDI
# 5268  None 2018-08-23 18:16:00         NaN
#
# [5269 rows x 14 columns]

# %%
def pop_rec(user,popular_info,user_info):
    purchased = user_info.loc[user_info.reviewerID==user,'asin']
    recs = popular_info.drop(index=purchased)
    return recs.index[:5]

# %%
recs = pop_rec('A3SFRT223XXWF7',popular_products,df)

# %%
recs
# Out:
# Index(['B000URXP6E', 'B0009RF9DW', 'B000FI4S1E', 'B00W259T7G', 'B0010ZBORW'], dtype='object', name='asin')

# %%
df['next_item'] = df.groupby('reviewerID')['asin'].shift(-1)

# %%
df.loc[df['asin']=='B01DLR9IDI','reviewerID'].value_counts()
# Out:
# reviewerID
# AUX122XW8ONG6     11
# A11QGZ39A7ZF0X    10
# Name: count, dtype: int64

# %%
def next_item(df,user):
  last_item = list(df[df.reviewerID==user]['asin'])[-1]
  purchased = list(df.loc[df.reviewerID==user,'asin'])
  next_item_list = list(df.loc[df.asin==last_item,'next_item'].value_counts().index)
  next_item_list_final = [item for item in next_item_list if item not in purchased]
  next_items = next_item_list_final[:5]
  return next_items

# %%
next_item(df,'A3J034YH7UG4KT')
# Out:
# ['B01E7UKR38']

# %%
last = list(df[df.reviewerID=='AUX122XW8ONG6']['asin'])[-1]

# %%
purchased = list(df.loc[df.reviewerID=='AUX122XW8ONG6','asin'])
purchased
# Out:
# ['B01DLR9IDI',
#  'B01DLR9IDI',
#  'B01DLR9IDI',
#  'B01DLR9IDI',
#  'B01DLR9IDI',
#  'B01DLR9IDI',
#  'B01DLR9IDI',
#  'B01DLR9IDI',
#  'B01DLR9IDI',
#  'B01DLR9IDI',
#  'B01DLR9IDI']

# %%
next_item_list = list(df.loc[df.asin==last,'next_item'].value_counts().index)

# %%
next_item_list
# Out:
# ['B01DLR9IDI']

# %%
next_item(df,'AUX122XW8ONG6')

# %%
items
# Out:
# [19]
